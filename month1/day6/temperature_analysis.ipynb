# %%
import numpy as np

temperatures = np.array([
    30, 32, 35, 33, 31, 29, 36
])

report = {
    "Average Temperature": np.mean(temperatures),
    "Highest Temperature": np.max(temperatures),
    "Lowest Temperature": np.min(temperatures),
    "Hot Days": temperatures[temperatures > 32],
}

report
# Out:
# {'Average Temperature': np.float64(32.285714285714285),
#  'Highest Temperature': np.int64(36),
#  'Lowest Temperature': np.int64(29),
#  'Hot Days': array([35, 33, 36])}
