# %% [markdown]
# # NumPy Basics
# Learning arrays and mathematical operations.

# %%
import numpy as np

# %%
numbers = np.array([10, 20, 30, 40, 50])
numbers
# Out:
# array([10, 20, 30, 40, 50])

# %%
numbers.shape
# Out:
# (5,)

# %%
numbers.dtype
# Out:
# dtype('int64')
