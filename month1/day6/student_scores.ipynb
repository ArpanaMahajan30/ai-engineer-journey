# %%
import numpy as np

scores = np.array([85, 92, 78, 90, 88, 76, 95, 89])

report = {
    "Total Students": scores.size,
    "Average Score": scores.mean(),
    "Highest Score": scores.max(),
    "Lowest Score": scores.min(),
    "Total Score": scores.sum()
}

report
# Out:
# {'Total Students': 8,
#  'Average Score': np.float64(86.625),
#  'Highest Score': np.int64(95),
#  'Lowest Score': np.int64(76),
#  'Total Score': np.int64(693)}
